# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import random
import pathlib
import shutil
import os.path
from os import path
path_1="/content/Fish_Image/bodianus"
path_2="/content/Fish_Image/coris"
path_3="/content/Fish_Image/epinephelus"
path_4="/content/Fish_Image/halichoeres"
path_5="/content/Fish_Image/lethrinus"
path_6="/content/Fish_Image/lutjanus"
path_7="/content/Fish_Image/pseudanthias"
path_8="/content/Fish_Image/thalassoma"

# %%
def import_dataset():
 if (not path.exists(path_1)):
  # !unzip "/content/drive/MyDrive/FishKaggle/archive (3).zip" -d "/content/"
  os.mkdir("/content/Fish_Image/")
  # !unrar x "/content/drive/MyDrive/FishKaggle/Talipia.rar" -d "/content/Fish_Image"
  os.mkdir(path_1)
  os.mkdir(path_2)
  os.mkdir(path_3)
  os.mkdir(path_4)  
  os.mkdir(path_5)
  os.mkdir(path_6)
  os.mkdir(path_7)
  os.mkdir(path_8)

# %% [markdown]
# # New Section

# %%
def class_classification(images):

  for image in images: 
   if ("bodianus" in str(image)):
    shutil.copy(image,path_1)
   elif ("coris" in str(image)):
    shutil.copy(image,path_2)
   elif ("epinephelus" in str(image)):
    shutil.copy(image,path_3)
   elif ("halichoeres" in str(image)):
    shutil.copy(image,path_4)
   elif ("lethrinus" in str(image)):
    shutil.copy(image,path_5) 
   elif ("lutjanus" in str(image)):
    shutil.copy(image,path_6)
   elif ("pseudanthias" in str(image)):
    shutil.copy(image,path_7)
   elif ("thalassoma" in str(image)):
    shutil.copy(image,path_8)

# %%
import_dataset()
data_dir_raw = pathlib.Path("/content/Fish_Data/images/raw_images")
data_dir_cropped = pathlib.Path("/content/Fish_Data/images/cropped")
images = list(data_dir_raw.glob('*')) + list(data_dir_cropped.glob('*')) 
class_classification(images)
data_dir="/content/Fish_Image/"
batch_size = 256
img_height = 180
img_width = 180
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir,validation_split=0.2,subset="training",seed=123,image_size=(img_height, img_width),batch_size=batch_size,labels='inferred',label_mode='categorical')
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir,validation_split=0.2,subset="validation",seed=123,image_size=(img_height, img_width),batch_size=batch_size,labels='inferred',label_mode='categorical')

#train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
#val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
num_classes = 9




                             
model_3 = tf.keras.Sequential([layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
                             layers.Conv2D(32, 11, activation='relu'),
                             #layers.MaxPooling2D(),
                             layers.Conv2D(32, 5, activation='relu'),
                             layers.MaxPooling2D(),
                             layers.Dropout(0.2),
                             layers.Flatten(),
                             layers.Dense(256, activation='relu'),
                             layers.Dense(num_classes, activation = 'softmax')])

#model_3.compile(optimizer='adam',loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics=['accuracy'])
model_3.compile(loss= "categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)



history = model_3.fit(train_ds,validation_data=val_ds,epochs=21)
model_3.summary()
# Out:
# Found 3145 files belonging to 9 classes.
# Using 2516 files for training.
# Found 3145 files belonging to 9 classes.
# Using 629 files for validation.
# Epoch 1/21
# 10/10 [==============================] - 660s 65s/step - loss: 6.2522 - accuracy: 0.1761 - val_loss: 2.1277 - val_accuracy: 0.2051
# Epoch 2/21
# 10/10 [==============================] - 661s 65s/step - loss: 2.1397 - accuracy: 0.2464 - val_loss: 1.9341 - val_accuracy: 0.2623
# Epoch 3/21
# 10/10 [==============================] - 656s 65s/step - loss: 1.8153 - accuracy: 0.3665 - val_loss: 1.6967 - val_accuracy: 0.4006
# Epoch 4/21
# 10/10 [==============================] - 663s 66s/step - loss: 1.5510 - accuracy: 0.4722 - val_loss: 2.0934 - val_accuracy: 0.3831
# Epoch 5/21
# 10/10 [==============================] - 655s 65s/step - loss: 1.6412 - accuracy: 0.4849 - val_loss: 1.6806 - val_accuracy: 0.4769
# Epoch 6/21
# 10/10 [==============================] - 645s 64s/step - loss: 1.2446 - accuracy: 0.6029 - val_loss: 1.3969 - val_accuracy: 0.5501
# Epoch 7/21
# 10/10 [==============================] - 656s 66s/step - loss: 0.8782 - accuracy: 0.7079 - val_loss: 1.2380 - val_accuracy: 0.6200
# Epoch 8/21
# 10/10 [==============================] - 666s 65s/step - loss: 0.6162 - accuracy: 0.7973 - val_loss: 1.1733 - val_accuracy: 0.6614
# Epoch 9/21
# 10/10 [==============================] - 670s 66s/step - loss: 0.4210 - accuracy: 0.8700 - val_loss: 1.2177 - val_accuracy: 0.6582
# Epoch 10/21
# 10/10 [==============================] - 660s 65s/step - loss: 0.2787 - accuracy: 0.9217 - val_loss: 1.2230 - val_accuracy: 0.6963
# Epoch 11/21
# 10/10 [==============================] - 667s 66s/step - loss: 0.1776 - accuracy: 0.9539 - val_loss: 1.5659 - val_accuracy: 0.7043
# Epoch 12/21
# 10/10 [==============================] - 671s 67s/step - loss: 0.1193 - accuracy: 0.9694 - val_loss: 1.6186 - val_accuracy: 0.6916
# Epoch 13/21
# 10/10 [==============================] - 671s 67s/step - loss: 0.0711 - accuracy: 0.9833 - val_loss: 1.4066 - val_accuracy: 0.6979
# Epoch 14/21
# 10/10 [==============================] - 667s 67s/step - loss: 0.0500 - accuracy: 0.9905 - val_loss: 1.5978 - val_accuracy: 0.7043
# Epoch 15/21
# 10/10 [==============================] - 667s 66s/step - loss: 0.0262 - accuracy: 0.9972 - val_loss: 1.7376 - val_accuracy: 0.7107
# Epoch 16/21
# 10/10 [==============================] - 637s 63s/step - loss: 0.0159 - accuracy: 0.9976 - val_loss: 1.6471 - val_accuracy: 0.7107
# Epoch 17/21
# 10/10 [==============================] - 621s 62s/step - loss: 0.0089 - accuracy: 0.9984 - val_loss: 1.9512 - val_accuracy: 0.7043
# Epoch 18/21
# 10/10 [==============================] - 627s 63s/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 1.9449 - val_accuracy: 0.7059
# Epoch 19/21
# 10/10 [==============================] - 628s 62s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.9801 - val_accuracy: 0.6932
# Epoch 20/21
# 10/10 [==============================] - 619s 62s/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 1.9161 - val_accuracy: 0.7075
# Epoch 21/21
# 10/10 [==============================] - 620s 62s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.9664 - val_accuracy: 0.6948
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_3 (Rescaling)      (None, 180, 180, 3)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 170, 170, 32)      11648
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 166, 166, 32)      25632
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 83, 83, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 83, 83, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 220448)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               56434944
# _________________________________________________________________
# dense_7 (Dense)              (None, 9)                 2313
# =================================================================
# Total params: 56,474,537
# Trainable params: 56,474,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
from google.colab import drive
drive.mount('/content/drive')
